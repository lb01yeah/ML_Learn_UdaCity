# %% [markdown]
# ## 层次聚类和密度聚类
#
# ## hierarchical clustering
#
# ## density clustering
# DBSCAN
# 具有噪声的基于密度的聚类方法Density-based spatial clustering of applications with noise 指的是把密集聚类的点分为同一个类，其它的点标记为噪声

# %% [markdown]
# ## 层次聚类
# - 单连接聚类single link clustering
#  (在scikit-learn中实际是没有単连结聚类的)
# ### 以下三种是scikit-learn中凝聚聚类（agglomerative clustering）的一部分
# - 全连接聚类（complete link clustering）
# > 凝聚聚类不包括单连接聚类，但包括全连接聚类（complete link clustering）。
# 全连接聚类关注的是两个类两点的最远距离，定义为两个类之间的距离。
# - 组平均聚类average link
#
# - 离差平方和法ward's method
# > 把合并类时的变量最小化，类内的中心点，到类之间的中心点的距离。为scikit-learn中的默认方法
# ![ward_method.png](attachment:ward_method.png)
