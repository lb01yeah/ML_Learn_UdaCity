# %% [markdown]
# ## Bayes Theorem 贝叶斯理论
# 实际条件概率理论，
# ![bayes_theorem.png](attachment:bayes_theorem.png)

# %% [markdown]
# ## naive bayes朴素贝叶斯
# 朴素：
# p(A∩B)=p(A)p(B)前提是A和B是相互独立，但实际中大多会是相互融合的。
# 使用如下公式定义条件概率公式：
# P(A|B)P(B) = P(B|A)P(A)   即为P(A∩B)
# 多会忽略P(B)，公式为P(A|B) = P(B|A)P(A)
# ![nb01.png](attachment:nb01.png)
#
# 以下为朴素贝叶斯的核心
# ![nb02.png](attachment:nb02.png)
