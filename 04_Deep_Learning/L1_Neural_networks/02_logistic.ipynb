# %% [markdown]
# ### logistic
# 所有机器学习的基石——对数几率回归算法。基本上是这样的：
# - 获得数据
# - 选择一个随机模型
# - 计算误差
# - 最小化误差，获得更好的模型
# - 完成！
# #### 计算误差函数
# 我们详细讲解下。下个视频将介绍如何计算误差函数。
# ![ef.png](attachment:ef.png)
#
# ![ef2.png](attachment:ef2.png)

# %% [markdown]
# #### 最小化误差函数
#   首先随机取一些权重，计算器误差函数，逐渐迭代。
#
# - 分类正确，误差函数则较小；分类错误，误差函数则较大；
# 最小化误差函数，利用梯度下降法gradient decent。
#
# ## 梯度下降
# ![gd1.png](attachment:gd1.png)
#
# ![gd2.png](attachment:gd2.png)
#
# ![gd3.png](attachment:gd3.png)
#
# ### 感知器和梯度下降的区别
# ![perceptron.png](attachment:perceptron.png)
